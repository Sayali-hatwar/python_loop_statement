# %% [markdown]
# - **set doesn't allow other type inside apart from string and tuple and they both are immutable.**
# - **Even though update the set with tuples, set or list datatype it will add inside tuple as tuple datatype and individually not inside anything**
#
# * frnd = {'Chakshu','Sameer','Chaks','Mona','Lucky'}
# * frnd.update(('ria','Guru'),('Kiara','Dev'))
# * frnd.update(['Banni','Shikha'])
# * frnd.update({'Banni','Shikha'})
# * print(frnd)
# * Return --> {'Guru', 'Chakshu', 'Lucky', 'Shikha', 'Kiara', 'Chaks', 'Mona', 'Sameer', 'Dev', 'ria', 'Banni'}

# %%
sdata1 = {'a','b','c','d'}
print(sdata1)
# Out:
# {'a', 'b', 'c', 'd'}

# %%
sdata1[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sdata1[1]
#
# TypeError: 'set' object is not subscriptable

# %%
for v in sdata1:
    print(v)
# Out:
# a
# b
# c
# d

# %%
sdata1.add('Apple')
sdata1
# Out:
# {'Apple', 'a', 'b', 'c', 'd'}

# %%
sdata1.discard('Piggi')  # if not found no error shows
sdata1.remove('Piggi')  # if not found error shows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 sdata1.discard('Piggi')
# ----> 2 sdata1.remove('Piggi')
#
# KeyError: 'Piggi'

# %%
sdata1.discard('Piggi')
sdata1.remove('Apple')

# %%
s1 = {1,2,4}
s2 = {3,2,1}

print(f"union = {s1|s2}")
print(f"union = {s1&s2}")

print(f"difference = {s1-s2}") ## shows those values which are only in s1 but not in s2
print(f"difference = {s2-s1}")  ## shows those values which are only in s2 but not in s1
# Out:
# union = {1, 2, 3, 4}
# union = {1, 2}
# difference = {4}
# difference = {3}
