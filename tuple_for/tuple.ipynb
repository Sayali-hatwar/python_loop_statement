# %%
tdata1 = ('a','b','c')

print(f"tdata1 = {tdata1}, type of tdata1 = {type(tdata1)}, len of tdata1 = {len(tdata1)}")
# Out:
# tdata1 = ('a', 'b', 'c'), type of tdata1 = <class 'tuple'>, len of tdata1 = 3

# %%
print(f"tdata1 = {tdata1[0]}, type of tdata1 = {type(tdata1[0])}, len of tdata1 = {len(tdata1)}")
print(f"tdata1 = {tdata1[1]}, type of tdata1 = {type(tdata1[1])}, len of tdata1 = {len(tdata1)}")
print(f"tdata1 = {tdata1[2]}, type of tdata1 = {type(tdata1[2])}, len of tdata1 = {len(tdata1)}")
print(f"tdata1 = {tdata1[3]}, type of tdata1 = {type(tdata1[3])}, len of tdata1 = {len(tdata1)}")

## as there is no value for 3 rd index
# Out:
# tdata1 = a, type of tdata1 = <class 'str'>, len of tdata1 = 3
# tdata1 = b, type of tdata1 = <class 'str'>, len of tdata1 = 3
# tdata1 = c, type of tdata1 = <class 'str'>, len of tdata1 = 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(f"tdata1 = {tdata1[1]}, type of tdata1 = {type(tdata1[1])}, len of tdata1 = {len(tdata1)}")
#       3 print(f"tdata1 = {tdata1[2]}, type of tdata1 = {type(tdata1[2])}, len of tdata1 = {len(tdata1)}")
# ----> 4 print(f"tdata1 = {tdata1[3]}, type of tdata1 = {type(tdata1[3])}, len of tdata1 = {len(tdata1)}")
#
# IndexError: tuple index out of range

# %%
print(tdata1[0:1])
print(tdata1[-1])
print(tdata1[::-1])
# Out:
# ('a',)
# c
# ('c', 'b', 'a')

# %%
tdata1 = 'Complete change'
print(tdata1)
# Out:
# Complete change

# %%
t2 = ('g',1,{'name':'mona'},[1,3,5])
t2
# Out:
# ('g', 1, {'name': 'mona'}, [1, 3, 5])

# %%
print(t2[2].get('name'))
# Out:
# mona

# %%
for i in t2:
    t = i
    print(t)
# Out:
# g
# 1
# {'name': 'mona'}
# [1, 3, 5]

# %%
t2 = ('g',1,{'name':'mona'},[1,3,5])

print(f"t = {t2}")
print(f"type of t = {type(t2)}")
ls = list(t2)
print(f"ls = {ls}") 
print(f"type of ls = {type(ls)}")
# Out:
# t = ('g', 1, {'name': 'mona'}, [1, 3, 5])
# type of t = <class 'tuple'>
# ls = ['g', 1, {'name': 'mona'}, [1, 3, 5]]
# type of ls = <class 'list'>
